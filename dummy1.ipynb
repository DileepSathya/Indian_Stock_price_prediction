# %%
import pandas as pd
df=pd.read_csv('updated data.csv')
df.head()
# Out:
#   Symbol   Series       Date    Prev Close    Open Price    High Price    \
# 0      NaN      NaN        NaN           NaN           NaN           NaN
# 1     ONGC       EQ   6-Oct-23        182.20         183.5         184.0
# 2     ONGC       EQ   9-Oct-23        181.45         182.9         183.5
# 3     ONGC       EQ  10-Oct-23        181.70         182.3         184.7
# 4     ONGC       EQ  11-Oct-23        183.50         184.4         184.5
#
#    Low Price    Last Price    Close Price    Average Price   \
# 0          NaN           NaN            NaN             NaN
# 1       181.00        181.50         181.45          182.72
# 2       180.60        182.20         181.70          181.34
# 3       181.25        183.35         183.50          182.73
# 4       182.05        183.00         183.25          183.73
#
#   Total Traded Quantity         Turnover ₹   No. of Trades    \
# 0                     NaN                NaN             NaN
# ...

# %% [markdown]
# Extract day
# remove series
# add gap open price -previous close

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Symbol                    251 non-null    object
#  1   Series                    251 non-null    object
#  2   Date                      251 non-null    object
#  3   Prev Close                251 non-null    float64
#  4   Open Price                251 non-null    float64
#  5   High Price                251 non-null    float64
#  6   Low Price                 251 non-null    float64
#  7   Last Price                251 non-null    float64
#  8   Close Price               251 non-null    float64
#  9   Average Price             251 non-null    float64
#  10  Total Traded Quantity     251 non-null    object
#  11  Turnover ₹                251 non-null    object
#  12  No. of Trades             251 non-null    object
# ...

# %%
list(df.columns)
# Out:
# ['Symbol  ',
#  'Series  ',
#  'Date  ',
#  'Prev Close  ',
#  'Open Price  ',
#  'High Price  ',
#  'Low Price  ',
#  'Last Price  ',
#  'Close Price  ',
#  'Average Price ',
#  'Total Traded Quantity  ',
#  'Turnover ₹  ',
#  'No. of Trades  ',
#  'Deliverable Qty  ',
#  '% Dly Qt to Traded Qty  ']

# %%
df.tail()
# Out:
#     Symbol   Series       Date    Prev Close    Open Price    High Price    \
# 246     ONGC       EQ  27-Sep-24        295.20         292.7        298.70
# 247     ONGC       EQ  30-Sep-24        297.20         297.0        298.45
# 248     ONGC       EQ   1-Oct-24        297.60         297.0        301.80
# 249     ONGC       EQ   3-Oct-24        291.95         295.0        299.15
# 250     ONGC       EQ   4-Oct-24        292.05         297.0        298.00
#
#      Low Price    Last Price    Close Price    Average Price   \
# 246       291.50         295.7         297.20          294.39
# 247       289.70         296.8         297.60          294.93
# 248       293.75         292.4         291.95          297.92
# 249       290.70         293.0         292.05          294.22
# 250       290.55         295.5         295.25          294.00
#
#     Total Traded Quantity          Turnover ₹   No. of Trades    \
# 246             2,78,12,412   8,18,77,97,967.40        2,07,121
# ...
