# %%
import pandas as pd
import os
colums=[5,6,9,10,11,12,13,14]
final=pd.DataFrame()
path = "C://Users//Dileep Sathya//OneDrive//Desktop//projects//stock price prediction//new_EQ_data"
dir_list = os.listdir(path)


for file in dir_list:
    df=pd.read_csv('new_EQ_data//'+file)


    # Specify the row and column to shift
    for cols in colums:
            column_index = cols  # Column B corresponds to index 1 (0-based index)
            start_row = 0  # Specify the row (5th row in 0-based index)
            shift_by = 1  # Specify the number of rows to shift down

            # Shift the specified cell and all cells below it down by the specified amount
            df.iloc[start_row + shift_by:, column_index] = df.iloc[start_row:-shift_by, column_index].values

            # Clear the original cell
            df.iloc[start_row, column_index] = None
    df=df.dropna()
    final=pd.concat([df,final],axis=0)

# %%
final.head()
# Out:
#   Symbol   Series         Date   Prev Close   Open Price   High Price    \
# 1     VEDL       EQ  06-Oct-2023        222.0       222.65        225.6
# 2     VEDL       EQ  09-Oct-2023        222.7       219.95        224.1
# 3     VEDL       EQ  10-Oct-2023       218.95        219.2        221.2
# 4     VEDL       EQ  11-Oct-2023       222.15        222.4        224.0
# 5     VEDL       EQ  12-Oct-2023       227.65        226.0       229.95
#
#   Low Price   Last Price   Close Price   Average Price   \
# 1      220.05       222.45         222.7         222.57
# 2      220.85        218.7        218.95         222.41
# 3      217.35       221.35        222.15         219.31
# 4      218.65        227.2        227.65         220.94
# 5      222.15        226.5         226.2         227.23
#
#   Total Traded Quantity         Turnover ₹   No. of Trades    \
# 1             1,01,55,103  2,26,01,90,251.40          91,043
# 2               55,23,734  1,22,85,07,124.80          58,323
# ...

# %% [markdown]
# ### Remove extra spaces in column names

# %%
final.columns = final.columns.str.strip()

# %%
final=final.rename(columns={'Prev Close':'prev_close','High Price':'prev_High_Price','Low Price':'prev_Low_Price','Average Price':'prev_Average_Price','Total Traded Quantity':'prev_Total_Traded_Quantity','Turnover ₹':'prev_Turnover','Deliverable Qty':'prev_Deliverable_Qty','% Dly Qt to Traded Qty':'prev_Dly_Qt_to_Traded_Qty'})

# %%
final.head()
# Out:
#   Symbol Series         Date prev_close Open Price prev_High_Price  \
# 1   VEDL     EQ  06-Oct-2023      222.0     222.65           225.6
# 2   VEDL     EQ  09-Oct-2023      222.7     219.95           224.1
# 3   VEDL     EQ  10-Oct-2023     218.95      219.2           221.2
# 4   VEDL     EQ  11-Oct-2023     222.15      222.4           224.0
# 5   VEDL     EQ  12-Oct-2023     227.65      226.0          229.95
#
#   prev_Low_Price Last Price Close Price prev_Average_Price  \
# 1         220.05     222.45       222.7             222.57
# 2         220.85      218.7      218.95             222.41
# 3         217.35     221.35      222.15             219.31
# 4         218.65      227.2      227.65             220.94
# 5         222.15      226.5       226.2             227.23
#
#   prev_Total_Traded_Quantity      prev_Turnover No. of Trades  \
# 1                1,01,55,103  2,26,01,90,251.40        91,043
# 2                  55,23,734  1,22,85,07,124.80        58,323
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53397 entries, 1 to 250
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Symbol                      53397 non-null  object
#  1   Series                      53397 non-null  object
#  2   Date                        53397 non-null  object
#  3   prev_close                  53397 non-null  object
#  4   Open Price                  53397 non-null  object
#  5   prev_High_Price             53397 non-null  object
#  6   prev_Low_Price              53397 non-null  object
#  7   Last Price                  53397 non-null  object
#  8   Close Price                 53397 non-null  object
#  9   prev_Average_Price          53397 non-null  object
#  10  prev_Total_Traded_Quantity  53397 non-null  object
#  11  prev_Turnover               53397 non-null  object
#  12  No. of Trades               53397 non-null  object
# ...

# %%
final.columns
# Out:
# Index(['Symbol', 'Series', 'Date', 'prev_close', 'Open Price',
#        'prev_High_Price', 'prev_Low_Price', 'Last Price', 'Close Price',
#        'prev_Average_Price', 'prev_Total_Traded_Quantity', 'prev_Turnover',
#        'No. of Trades', 'prev_Deliverable_Qty', 'prev_Dly_Qt_to_Traded_Qty'],
#       dtype='object')

# %%
for col in final.columns:
    if col not in ['Symbol', 'Date', 'Series', 'prev_Dly_Qt_to_Traded_Qty']:
        if final[col].dtype == 'object':
            final[col] = final[col].apply(lambda x: str(x).replace(',', '') if isinstance(x, str) else x)

            final[col] = pd.to_numeric(final[col], errors='coerce')

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53397 entries, 1 to 250
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Symbol                      53397 non-null  object
#  1   Series                      53397 non-null  object
#  2   Date                        53397 non-null  object
#  3   prev_close                  53397 non-null  float64
#  4   Open Price                  53397 non-null  float64
#  5   prev_High_Price             53397 non-null  float64
#  6   prev_Low_Price              53397 non-null  float64
#  7   Last Price                  53397 non-null  float64
#  8   Close Price                 53397 non-null  float64
#  9   prev_Average_Price          53397 non-null  float64
#  10  prev_Total_Traded_Quantity  53397 non-null  int64
#  11  prev_Turnover               53397 non-null  float64
#  12  No. of Trades               53397 non-null  int64
# ...

# %%
final['gap']=final['Open Price']-final['prev_close']

# %%
final.head()
# Out:
#   Symbol Series         Date  prev_close  Open Price  prev_High_Price  \
# 1   VEDL     EQ  06-Oct-2023      222.00      222.65           225.60
# 2   VEDL     EQ  09-Oct-2023      222.70      219.95           224.10
# 3   VEDL     EQ  10-Oct-2023      218.95      219.20           221.20
# 4   VEDL     EQ  11-Oct-2023      222.15      222.40           224.00
# 5   VEDL     EQ  12-Oct-2023      227.65      226.00           229.95
#
#    prev_Low_Price  Last Price  Close Price  prev_Average_Price  \
# 1          220.05      222.45       222.70              222.57
# 2          220.85      218.70       218.95              222.41
# 3          217.35      221.35       222.15              219.31
# 4          218.65      227.20       227.65              220.94
# 5          222.15      226.50       226.20              227.23
#
#    prev_Total_Traded_Quantity  prev_Turnover  No. of Trades  \
# 1                    10155103   2.260190e+09          91043
# ...
